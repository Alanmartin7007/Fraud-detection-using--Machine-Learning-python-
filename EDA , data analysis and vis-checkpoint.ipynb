# %%
import matplotlib.pyplot as plt
import pandas as pd

# merged two dataframes to one dataframe
df1 = pd.read_csv('Customer_DF.csv')
df2 = pd.read_csv('cust_transaction_details.csv')
df = df1.merge(df2, on='customerEmail')

# Checking the data type
# print(df.dtypes)

# Dropping irrelevant columns
df = df.drop(['Unnamed: 0_x', 'customerEmail', 'customerPhone', 'customerDevice', 'customerIPAddress', 'customerBillingAddress', 'Unnamed: 0_y', 'transactionId', 'orderId', 'paymentMethodId'], axis=1)
# print(df.dtypes)

# Total number of rows and columns
total_number_of_rows = df.shape
print(" total number of rows and columns ", total_number_of_rows)

# Rows containing duplicate data
duplicate_rows_df = df[df.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)

# Used to count the number of rows before removing the data
print(df.count())

df = df.drop_duplicates()

# Count the number of rows after removing the data
print(df.count())

# no column with null values , so no need to drop the missing or null values.

# next step
# plot bar graph for which payment has more fraudulent transactions ::: my method
df.groupby(['paymentMethodType', 'Fraud']).size().unstack().plot(kind='barh', stacked=True, title='Payment mode and Fraud Percentage', mark_right=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6c998f7c8ab8> in <module>
#       3
#       4 # merged two dataframes to one dataframe
# ----> 5 df1 = pd.read_csv('Customer_DF.csv')
#       6 df2 = pd.read_csv('cust_transaction_details.csv')
#       7 df = df1.merge(df2, on='customerEmail')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Customer_DF.csv' does not exist: b'Customer_DF.csv'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline
#import missingno as msno
from IPython.display import Markdown
def bold(string):
    display(Markdown(string))



data = pd.read_csv('C:/Users/pc1/Desktop/Major Project ver/Customer_DF.csv', header = None)
data.columns = data.iloc[0]
data = data[1:]
display(data.head(5))
print('Dimension of data:', data.shape)
# Out:
# 0  NaN              customerEmail       customerPhone        customerDevice  \
# 1  0.0     josephhoward@yahoo.com        400-108-5415  yyeiaxpltf82440jnb3v
# 2  1.0     evansjeffery@yahoo.com      1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 3  2.0  andersonwilliam@yahoo.com        024.420.0375  4m7h5ipl1shyavt6vv2r
# 4  3.0      rubenjuarez@yahoo.com  670.664.8168x94985  slovx60t0i558may4ks0
# 5  4.0           uchen@malone.com      1-981-877-0870  j0pd24k5h8dl2fqu0cz4
#
# 0                        customerIPAddress  \
# 1                             8.129.104.40
# 2                          219.173.211.202
# 3  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 4  95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 5                           196.89.235.192
#
# 0                             customerBillingAddress No_Transactions  \
# 1            5493 Jones Islands\nBrownside, CA 51896               2
# 2  356 Elizabeth Inlet Suite 120\nPort Joshuabury...               3
# 3     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250               5
# 4  7769 Elizabeth Bridge Apt. 343\nNortonstad, FM...               3
# 5  148 Russell Lodge Apt. 445\nPort Jenniferside,...               7
#
# 0 No_Orders No_Payments  Fraud
# 1         2           1  False
# 2         3           7   True
# 3         3           2  False
# 4         3           1  False
# 5         7           6   True
# Dimension of data: (168, 10)

# %%
data2 = pd.read_csv('C:/Users/pc1/Desktop/Major Project ver/cust_transaction_details.csv', header = None)
data2.columns = data2.iloc[0]
data2 = data2[1:]
display(data2.head(5))
print('Dimension of data:', data2.shape)
# Out:
# 0  NaN           customerEmail transactionId orderId paymentMethodId  \
# 1  0.0  josephhoward@yahoo.com      a9lcj51r  vjbdvd       wt07xm68b
# 2  1.0  josephhoward@yahoo.com      y4wcv03i  yp6x27       wt07xm68b
# 3  2.0  evansjeffery@yahoo.com      5mi94sfw  nlghpa       41ug157xz
# 4  3.0  evansjeffery@yahoo.com      br8ba1nu  uw0eeb       41ug157xz
# 5  4.0  evansjeffery@yahoo.com      a33145ss  bn44oh       y3xp697jx
#
# 0 paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 1                                1              card          JCB 16 digit
# 2                                1              card          JCB 16 digit
# 3                                0           bitcoin      American Express
# 4                                0           bitcoin      American Express
# 5                                1           bitcoin         VISA 16 digit
#
# 0 transactionAmount transactionFailed orderState
# 1                18                 0    pending
# 2                26                 0  fulfilled
# 3                45                 0  fulfilled
# 4                23                 0  fulfilled
# 5                43                 1  fulfilled
# Dimension of data: (623, 11)

# %%
sns.jointplot(x='paymentMethodType', y='transactionAmount', data=data2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d9956210891c> in <module>
# ----> 1 sns.jointplot(x='paymentMethodType', y='transactionAmount', data=data2)
#       2
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2292         marginal_kws.setdefault("kde", False)
#    2293         marginal_kws.setdefault("color", color)
# -> 2294         grid.plot_marginals(distplot, **marginal_kws)
#    2295
#    2296     elif kind.startswith("hex"):
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1807         kwargs["vertical"] = False
#    1808         plt.sca(self.ax_marg_x)
# -> 1809         func(self.x, **kwargs)
#    1810
#    1811         kwargs["vertical"] = True
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      32     if len(a) < 2:
#      33         return 1
# ---> 34     h = 2 * iqr(a) / (len(a) ** (1 / 3))
#      35     # fall back to sqrt(a) bins if iqr is 0
#      36     if h == 0:
#
# ~\Anaconda3\lib\site-packages\seaborn\utils.py in iqr(a)
#     364     """Calculate the IQR for an array of numbers."""
#     365     a = np.asarray(a)
# --> 366     q1 = stats.scoreatpercentile(a, 25)
#     367     q3 = stats.scoreatpercentile(a, 75)
#     368     return q3 - q1
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in scoreatpercentile(a, per, limit, interpolation_method, axis)
#    1729         axis = 0
#    1730
# -> 1731     return _compute_qth_percentile(sorted_, per, interpolation_method, axis)
#    1732
#    1733
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in _compute_qth_percentile(sorted_, per, interpolation_method, axis)
#    1773
#    1774     # Use np.add.reduce (== np.sum but a little faster) to coerce data type
# -> 1775     return np.add.reduce(sorted_[tuple(indexer)] * weights, axis=axis) / sumval
#    1776
#    1777
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
sns.pairplot(data2)

# %%
sns.lmplot(x='No_Transactions', y='No_Orders', data=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7b88e12088c6> in <module>
# ----> 1 sns.lmplot(x='No_Transactions', y='No_Orders', data=data)
#
# NameError: name 'data' is not defined

# %%
sns.set_palette('GnBu_d')
sns.set_style('whitegrid')
sns.jointplot(x='paymentMethodType', y='transactionAmount', data=data2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-6a87b24790e8> in <module>
#       1 sns.set_palette('GnBu_d')
#       2 sns.set_style('whitegrid')
# ----> 3 sns.jointplot(x='paymentMethodType', y='transactionAmount', data=data2)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2292         marginal_kws.setdefault("kde", False)
#    2293         marginal_kws.setdefault("color", color)
# -> 2294         grid.plot_marginals(distplot, **marginal_kws)
#    2295
#    2296     elif kind.startswith("hex"):
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1807         kwargs["vertical"] = False
#    1808         plt.sca(self.ax_marg_x)
# -> 1809         func(self.x, **kwargs)
#    1810
#    1811         kwargs["vertical"] = True
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      32     if len(a) < 2:
#      33         return 1
# ---> 34     h = 2 * iqr(a) / (len(a) ** (1 / 3))
#      35     # fall back to sqrt(a) bins if iqr is 0
#      36     if h == 0:
#
# ~\Anaconda3\lib\site-packages\seaborn\utils.py in iqr(a)
#     364     """Calculate the IQR for an array of numbers."""
#     365     a = np.asarray(a)
# --> 366     q1 = stats.scoreatpercentile(a, 25)
#     367     q3 = stats.scoreatpercentile(a, 75)
#     368     return q3 - q1
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in scoreatpercentile(a, per, limit, interpolation_method, axis)
#    1729         axis = 0
#    1730
# -> 1731     return _compute_qth_percentile(sorted_, per, interpolation_method, axis)
#    1732
#    1733
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in _compute_qth_percentile(sorted_, per, interpolation_method, axis)
#    1773
#    1774     # Use np.add.reduce (== np.sum but a little faster) to coerce data type
# -> 1775     return np.add.reduce(sorted_[tuple(indexer)] * weights, axis=axis) / sumval
#    1776
#    1777
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print('total customer records', data.shape[0], 'total unique customer' ,len(data.customerEmail.unique()))
# Out:
# total customer records 168 total unique customer 161

# %%
data[data['customerEmail'].duplicated()]
#As there are 8 duplicate mails in data, so all these are assumed as fraudlent.Creating a new column to detect these.
# Out:
# 0      NaN         customerEmail       customerPhone        customerDevice  \
# 41    40.0  johnlowery@gmail.com    737-377-9701x577  jz66ap43id2y35ivfqa5
# 46    45.0  johnlowery@gmail.com    +16(4)9016414340  cdx178qymd6vy77nm4x3
# 66    65.0  johnlowery@gmail.com         04712252182  311kdz4c1210iixltk2j
# 80    79.0  johnlowery@gmail.com  1-820-539-4726x993  2in0fh7lep289n8dcbdz
# 134  133.0  johnlowery@gmail.com      1-143-059-1833  tyijaify2hqadwslejyr
# 156  155.0  johnlowery@gmail.com  076-099-0630x72770  6qy6oa3nqutsyyxzc54c
# 166  165.0  johnlowery@gmail.com    635.676.0955x524  969zz9zdj8z4gns4sx5p
#
# 0                          customerIPAddress  \
# 41   6c21:ac1d:2089:68fa:abb7:8c00:525f:6588
# 46                            222.79.159.140
# 66    42b3:df19:86fe:abd9:dafe:f6c1:eb76:c72
# 80                            163.128.139.42
# 134   e4c:fb48:8ee2:9819:6ae8:8d3f:3b6a:a788
# 156  f259:657f:f329:2fca:c06c:8b57:d6ac:2380
# 166   f82c:811f:8a02:e2d6:79b:fcaa:42de:570b
#
# 0                               customerBillingAddress No_Transactions  \
# 41   08238 Kyle Squares Suite 893\nMillermouth, IN ...               0
# 46             77711 Pamela Ridge\nNew Kayla, IL 27182               3
# 66   11704 Andrew Villages Apt. 035\nJamesfurt, OR ...               7
# 80             814 Wagner Union\nAshleymouth, HI 35617               2
# 134  518 Wood Mews Apt. 970\nDillonstad, NE 43317-3945               0
# 156  687 Rogers Bridge Suite 780\nValdezburgh, IN 2...               6
# 166           548 Bryant Inlet\nVeronicaside, OK 00522               4
#
# 0   No_Orders No_Payments Fraud
# 41          0           1  True
# 46          2           1  True
# 66          5           1  True
# 80          2           1  True
# 134         0           0  True
# 156         5           3  True
# 166         4           2  True

# %%
data['Duplicate_Name'] = data['CustomerEmail'].apply(lambda x: 1 if (data[data.customerEmail==x]['customerEmail'].shape[0]>1)else 0)
data['Duplicate_IP'] = data['CustomerIPAddress'].apply(lambda x: 1 if (data[data.customerIPAddress==x]['CustomerIPAddress'].shape[0]>1)else 0)
data['Duplicate_Address'] = data['customerBillingAddress'].apply(lambda x: 1 if(data[data.customerBillingAddress==x]['customerBillingAddress'].shape[0]>1)else 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CustomerEmail'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-d0e234df5beb> in <module>
# ----> 1 data['Duplicate_Name'] = data['CustomerEmail'].apply(lambda x: 1 if (data[data.customerEmail==x]['customerEmail'].shape[0]>1)else 0)
#       2 data['Duplicate_IP'] = data['CustomerIPAddress'].apply(lambda x: 1 if (data[data.customerIPAddress==x]['CustomerIPAddress'].shape[0]>1)else 0)
#       3 data['Duplicate_Address'] = data['customerBillingAddress'].apply(lambda x: 1 if(data[data.customerBillingAddress==x]['customerBillingAddress'].shape[0]>1)else 0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CustomerEmail'

# %%
data.head()
# Out:
# 0  NaN              customerEmail       customerPhone        customerDevice  \
# 1  0.0     josephhoward@yahoo.com        400-108-5415  yyeiaxpltf82440jnb3v
# 2  1.0     evansjeffery@yahoo.com      1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 3  2.0  andersonwilliam@yahoo.com        024.420.0375  4m7h5ipl1shyavt6vv2r
# 4  3.0      rubenjuarez@yahoo.com  670.664.8168x94985  slovx60t0i558may4ks0
# 5  4.0           uchen@malone.com      1-981-877-0870  j0pd24k5h8dl2fqu0cz4
#
# 0                        customerIPAddress  \
# 1                             8.129.104.40
# 2                          219.173.211.202
# 3  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 4  95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 5                           196.89.235.192
#
# 0                             customerBillingAddress No_Transactions  \
# 1            5493 Jones Islands\nBrownside, CA 51896               2
# 2  356 Elizabeth Inlet Suite 120\nPort Joshuabury...               3
# 3     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250               5
# 4  7769 Elizabeth Bridge Apt. 343\nNortonstad, FM...               3
# 5  148 Russell Lodge Apt. 445\nPort Jenniferside,...               7
#
# 0 No_Orders No_Payments  Fraud
# 1         2           1  False
# 2         3           7   True
# 3         3           2  False
# 4         3           1  False
# 5         7           6   True

# %%
#Customer with maximum transactions 
data[data.No_Transactions==data.No_Transactions.max()]
# Out:
# 0      NaN                  customerEmail        customerPhone  \
# 26    25.0            karen54@mullins.biz       1-019-956-8013
# 43    42.0           brandon58@conner.com   726-715-7429x06218
# 57    56.0       ssmith@levine-harmon.biz   266-228-3021x90360
# 122  121.0              ctaylor@yahoo.com  1-020-923-6697x8718
# 167  166.0  ethompson@jackson-sanders.com         962.300.2250
#
# 0          customerDevice                        customerIPAddress  \
# 26   ybz490o0v5781808jtzw                           61.219.235.129
# 43   qywyyrk5r87k21ij3p62                           225.62.150.241
# 57   7u2y3wsyj7ehzfao86md  13ff:5a93:bc34:e190:5e4b:ac80:2e2d:6217
# 122  uu141ykhyig0cj3s98jr  dda2:66e0:4279:3c1b:ac29:4cbb:5ea3:c26b
# 167  navessqcnmc9csfjn5cj                          203.246.172.244
#
# 0                              customerBillingAddress No_Transactions  \
# 26   526 Ronald Cliffs\nWest Christinaville, GU 76418               8
# 43                        USS Barr\nFPO AE 16052-3851               8
# 57   37549 Crawford Forest\nChristopherside, KY 96656               8
# 122  87096 Warren Turnpike\nHowellview, WA 74727-2420               8
# 167  16953 Jennifer Springs\nKathybury, IL 02095-3215               8
#
# 0   No_Orders No_Payments  Fraud
# 26          5           2  False
# 43          3           1  False
# 57          5           2  False
# 122         6           6   True
# 167         6           6   True

# %%
#Customer with max Orders
data[data.No_Orders==data.No_Orders.max()]
# Out:
# 0      NaN                customerEmail         customerPhone  \
# 85    84.0  lleonard@turner-fleming.com  1-414-937-7421x73705
# 98    97.0          vmiller@hotmail.com          000-734-4774
# 99    98.0            david45@gmail.com         (508)223-3834
# 104  103.0        tmcpherson@wright.com  1-804-264-1481x08539
#
# 0          customerDevice                        customerIPAddress  \
# 85   yfpqgg5oxsn107veaala                             97.111.97.42
# 98   b1tjk5s0j9ybj1qpt3ik                             164.79.214.9
# 99   l6qv05oe0h0j78kx84ex  9d8d:535b:36fc:8773:bec0:8fa5:3206:4cb5
# 104  ui77ukzr5lnqpajdk03u  296d:59fe:a919:21ac:16dd:96f5:10b3:4f83
#
# 0                               customerBillingAddress No_Transactions  \
# 85      96103 Riley Walks\nMichellefort, ID 98085-6066              11
# 98               PSC 9111, Box 9839\nAPO AA 57283-9646              10
# 99   5360 Adams Falls Suite 829\nHensleymouth, WV 8...              10
# 104  7956 Alex Avenue Apt. 593\nPort Michael, OK 41350              13
#
# 0   No_Orders No_Payments Fraud
# 85          8           1  True
# 98          8           1  True
# 99          8           5  True
# 104         8           1  True

# %%
#Customer with max Payments
data[data.No_Payments==data.No_Payments.max()]
# Out:
# 0  NaN           customerEmail   customerPhone        customerDevice  \
# 2  1.0  evansjeffery@yahoo.com  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
#
# 0 customerIPAddress                             customerBillingAddress  \
# 2   219.173.211.202  356 Elizabeth Inlet Suite 120\nPort Joshuabury...
#
# 0 No_Transactions No_Orders No_Payments Fraud
# 2               3         3           7  True

# %%
data['Fraud_Found'] = data['Fraud'].apply(lambda x: 1 if x else 0)

# %%
import math
print('Average no. of Payments:',round(data.No_Payments.mean()))
print('Average no. of Transactions:',round(data.No_Transactions.mean()))
print('Average no. of Orders:',round(data.No_Orders.mean()))
# Out:
# Average no. of Payments: 1.0247751256804294e+168
# Average no. of Transactions: 1.4010194349252706e+171
# Average no. of Orders: 1.3891140003299132e+165

# %%
data.groupby(by=['Fraud'])['Fraud'].count().plot(kind='bar')
plt.title('Fraud count')
plt.show()

# %%
new_data = pd.melt(data[['No_Transactions', 'No_Orders', 'No_Payments', 'Fraud']], "Fraud", var_name="features")

plt.figure(figsize=(12,6))
sns.swarmplot(x="features", y="value", hue="Fraud", palette=['b','r','c'], data=new_data)
# Out:
# C:\Users\pc1\Anaconda3\lib\site-packages\seaborn\categorical.py:1243: RuntimeWarning: invalid value encountered in sqrt
#   dx = np.sqrt(d ** 2 - dy ** 2) * 1.05

# %%
#As fraudlent transactions not very clearly distinguished,let's visualize the model another way.

# %%
x = data[['No_Transactions','No_Orders','No_Payments']].values
y = data.Fraud_Found.values

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
X = tsne.fit_transform(x)

# %%
target_ids = range(2)

plt.figure(figsize=(10,6))
colors= 'r','g'

for i, c, label in zip(target_ids, colors,['True','False']):
    plt.scatter(X[y== i,0], X[y== i,1], c=c, label=label)
plt.legend()
plt.show()

# %%
#

# %%
#Checking if a customer that has not opted for any payment method,is fraud
data[data.No_Payments==0]
#If the no. of payment methods are zero and there are no duplicates, then customer isn't a fraud.
# Out:
# Empty DataFrame
# Columns: [nan, customerEmail, customerPhone, customerDevice, customerIPAddress, customerBillingAddress, No_Transactions, No_Orders, No_Payments, Fraud, Fraud_Found]
# Index: []

# %%
data2.paymentMethodType.unique()
# Out:
# array(['card', 'bitcoin', 'apple pay', 'paypal'], dtype=object)

# %%
# Insight of all successfull transactions done by a customer till date

data2[(data2.transactionFailed>0) & (data2.customerEmail=='vmiller@hotmail.com')].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-78ff9da64bff> in <module>
#       1 # Insight of all successfull transactions done by a customer till date
#       2
# ----> 3 data2[(data2.transactionFailed>0) & (data2.customerEmail=='vmiller@hotmail.com')].unique()
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
data2[(data2.orderState=='fulfilled')].sort_values(by=['customerEmail'])
# Out:
# 0      NaN      customerEmail transactionId orderId paymentMethodId  \
# 553  552.0      1yf0@jedyz63t      pkc9dfn2  st9dv0       0l7kszls7
# 552  551.0      1yf0@jedyz63t      i4edjdey  st9dv0       0l7kszls7
# 551  550.0      1yf0@jedyz63t      cnion0pc  st9dv0       0l7kszls7
# 544  543.0      1yf0@jedyz63t      foo56851  gcop7b       igpmsjd73
# 545  544.0      1yf0@jedyz63t      drngwa51  eftfwy       0l7kszls7
# ..     ...                ...           ...     ...             ...
# 418  417.0  zgraham@yahoo.com      93wgj32w  3g1bbj       ougmgyvof
# 417  416.0  zgraham@yahoo.com      cosa5rtj  9khtcz       ougmgyvof
# 416  415.0  zgraham@yahoo.com      82m0gkqr  0linjx       4lbflweug
# 415  414.0  zgraham@yahoo.com      tyhoucmk  4pg8fk       l4w49qskr
# 419  418.0  zgraham@yahoo.com      trxn5ehm  3g1bbj       4lbflweug
#
# 0   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 553                                0              card         VISA 13 digit
# 552                                0              card         VISA 13 digit
# 551                                0              card         VISA 13 digit
# 544                                0            paypal            Mastercard
# 545                                0              card         VISA 13 digit
# ..                               ...               ...                   ...
# 418                                0              card               Maestro
# 417                                0              card               Maestro
# 416                                0              card              Discover
# 415                                0         apple pay               Voyager
# 419                                0              card              Discover
#
# 0   transactionAmount transactionFailed orderState
# 553                12                 1  fulfilled
# 552                12                 1  fulfilled
# 551                12                 1  fulfilled
# 544                38                 0  fulfilled
# 545                11                 0  fulfilled
# ..                ...               ...        ...
# 418                11                 1  fulfilled
# 417                12                 0  fulfilled
# 416                43                 1  fulfilled
# 415                42                 0  fulfilled
# 419                11                 0  fulfilled
#
# [516 rows x 11 columns]

# %%
data[data.Fraud_Found==1]
# Out:
# 0      NaN                    customerEmail        customerPhone  \
# 1      0.0           josephhoward@yahoo.com         400-108-5415
# 2      1.0           evansjeffery@yahoo.com       1-788-091-7546
# 3      2.0        andersonwilliam@yahoo.com         024.420.0375
# 4      3.0            rubenjuarez@yahoo.com   670.664.8168x94985
# 5      4.0                 uchen@malone.com       1-981-877-0870
# ..     ...                              ...                  ...
# 164  163.0  mitchellvickie@brewer-jones.com    313-124-3836x3528
# 165  164.0                sbrown@hughes.biz  (250)632-6631x02499
# 166  165.0             johnlowery@gmail.com     635.676.0955x524
# 167  166.0    ethompson@jackson-sanders.com         962.300.2250
# 168  167.0          dawn05@tucker-brown.com   (089)703-7360x8848
#
# 0          customerDevice                        customerIPAddress  \
# 1    yyeiaxpltf82440jnb3v                             8.129.104.40
# 2    r0jpm7xaeqqa3kr6mzum                          219.173.211.202
# 3    4m7h5ipl1shyavt6vv2r  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 4    slovx60t0i558may4ks0  95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 5    j0pd24k5h8dl2fqu0cz4                           196.89.235.192
# ..                    ...                                      ...
# 164  ecu7ezz0ue67v3fce1o3                           181.90.104.120
# 165  xgv918sclaz40qlp2fee                               16.166.2.0
# 166  969zz9zdj8z4gns4sx5p   f82c:811f:8a02:e2d6:79b:fcaa:42de:570b
# 167  navessqcnmc9csfjn5cj                          203.246.172.244
# 168  lu4fgcug8dr0dwbcuui1                            132.132.95.33
#
# 0                               customerBillingAddress No_Transactions  \
# 1              5493 Jones Islands\nBrownside, CA 51896               2
# 2    356 Elizabeth Inlet Suite 120\nPort Joshuabury...               3
# 3       8478 Sean Ridges Apt. 441\nDavisberg, PR 72250               5
# 4    7769 Elizabeth Bridge Apt. 343\nNortonstad, FM...               3
# 5    148 Russell Lodge Apt. 445\nPort Jenniferside,...               7
# ..                                                 ...             ...
# 164  829 Ramirez Dam Suite 648\nGatesview, OR 55669...               3
# 165  9472 Pacheco Islands Suite 940\nDrewburgh, AZ ...               6
# 166           548 Bryant Inlet\nVeronicaside, OK 00522               4
# 167   16953 Jennifer Springs\nKathybury, IL 02095-3215               8
# 168   130 Kimberly Junctions\nEricmouth, KS 59756-2919               7
#
# 0   No_Orders No_Payments  Fraud  Fraud_Found
# 1           2           1  False            1
# 2           3           7   True            1
# 3           3           2  False            1
# 4           3           1  False            1
# 5           7           6   True            1
# ..        ...         ...    ...          ...
# 164         3           1   True            1
# 165         5           3   True            1
# 166         4           2   True            1
# 167         6           6   True            1
# 168         5           4  False            1
#
# [168 rows x 11 columns]

# %%
import os
from numpy import loadtxt
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import plot_importance
from matplotlib import pyplot
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2957f85b9ee7> in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from xgboost import XGBClassifier
#       6 from sklearn.model_selection import train_test_split
#       7 from sklearn.metrics import accuracy_score
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# Join dataset and produce the result dataframe
customer = pd.read_csv("customer.csv",index_col=False)
customer_df = customer[["customerEmail","No_Transactions","No_Orders","No_Payments","Fraud"]]
transaction = pd.read_csv("transaction.csv",index_col=False)
transaction_df = transaction[["customerEmail","paymentMethodType","transactionAmount","orderState","paymentMethodProvider"]]
print(customer_df.head())
print(transaction_df.head())
result = pd.merge(transaction_df,customer_df,on='customerEmail')
print(result.head())
# Out:
#                customerEmail  No_Transactions  No_Orders  No_Payments  Fraud
# 0     josephhoward@yahoo.com                2          2            1  False
# 1     evansjeffery@yahoo.com                3          3            7   True
# 2  andersonwilliam@yahoo.com                5          3            2  False
# 3      rubenjuarez@yahoo.com                3          3            1  False
# 4           uchen@malone.com                7          7            6   True
#             customerEmail paymentMethodType  transactionAmount orderState  \
# 0  josephhoward@yahoo.com              card                 18    pending
# 1  josephhoward@yahoo.com              card                 26  fulfilled
# 2  evansjeffery@yahoo.com           bitcoin                 45  fulfilled
# 3  evansjeffery@yahoo.com           bitcoin                 23  fulfilled
# 4  evansjeffery@yahoo.com           bitcoin                 43  fulfilled
#
#   paymentMethodProvider
# 0          JCB 16 digit
# 1          JCB 16 digit
# 2      American Express
# 3      American Express
# 4         VISA 16 digit
#             customerEmail paymentMethodType  transactionAmount orderState  \
# 0  josephhoward@yahoo.com              card                 18    pending
# 1  josephhoward@yahoo.com              card                 26  fulfilled
# 2  evansjeffery@yahoo.com           bitcoin                 45  fulfilled
# 3  evansjeffery@yahoo.com           bitcoin                 23  fulfilled
# 4  evansjeffery@yahoo.com           bitcoin                 43  fulfilled
#
#   paymentMethodProvider  No_Transactions  No_Orders  No_Payments  Fraud
# 0          JCB 16 digit                2          2            1  False
# 1          JCB 16 digit                2          2            1  False
# 2      American Express                3          3            7   True
# 3      American Express                3          3            7   True
# 4         VISA 16 digit                3          3            7   True
